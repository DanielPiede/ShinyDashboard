# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
path = Path(r"C:\Users\piede\OneDrive\Dokumente\Code\Shiny\ShinyDashboard\raw\OCED_simplified.csv")

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#      year     country  Immunisation: Hepatitis B_% of children immunised  \
# 0    2010   Australia                                               91.6
# 1    2011   Australia                                               91.6
# 2    2012   Australia                                               91.8
# 3    2013   Australia                                               91.0
# 4    2014   Australia                                               91.2
# ..    ...         ...                                                ...
# 514  2018    Colombia                                               92.0
# 515  2019    Colombia                                               94.0
# 516  2020    Colombia                                               87.9
# 517  2021    Colombia                                               87.9
# 518  2021  Costa Rica                                               87.4
#
#      Immunisation: Influenza_% of population aged 65 years and over  \
# ...

# %%
len(df.columns)
# Out:
# 718

# %%
df[['year', 'country', 'Crohn\'s disease and ulcerative colitis_Per 100 000 population']]
# Out:
#      year     country  \
# 0    2010   Australia
# 1    2011   Australia
# 2    2012   Australia
# 3    2013   Australia
# 4    2014   Australia
# ..    ...         ...
# 514  2018    Colombia
# 515  2019    Colombia
# 516  2020    Colombia
# 517  2021    Colombia
# 518  2021  Costa Rica
#
#      Crohn's disease and ulcerative colitis_Per 100 000 population
# 0                                                 30.6
# 1                                                 30.9
# 2                                                 32.3
# 3                                                 34.0
# 4                                                 33.7
# ..                                                 ...
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
#
# ...
